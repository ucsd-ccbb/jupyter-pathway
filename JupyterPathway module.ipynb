# %%
import sys
code_path = '/Users/Lilith/Desktop/LilithCCBB/PathwayViz'
sys.path.append(code_path)
import PathwayVisFunctions

import imp
imp.reload(PathwayVisFunctions)
# Out:
# /Users/Lilith/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# <module 'PathwayVisFunctions' from '/Users/Lilith/Desktop/LilithCCBB/PathwayViz/PathwayVisFunctions.pyc'>

# %%
# type in pathway key and True or False for edge redirection
PathwayVisFunctions.pathwayVisualization("hsa04010", "/Users/Lilith/data/DE_genes_converted.csv", True)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1700"];    frame.runVis([{"node_size": 10, "node_shape": "box", "y": 910.0, "degree": 1, "color": "#f1f1f1", "x": 620.0, "border_width": 1, "id_num": "GNA12", "id": "GNA12, NNX3, RMP, gep..."}, {"node_size": 10, "node_shape": "box", "y": 910.0, "degree": 1, "color": "#f1f1f1", "x": 690.0, "border_width": 1, "id_num": "GNG12", "id": "GNA12, NNX3, RMP, gep..."}, {"node_size": 10, "node_shape": "box", "y": 830.0, "degree": 3, "color": "#f1f1f1", "x": 515.0, "border_width": 1, "id_num": "PDGFRA", "id": "PDGFRA, CD140A, GAS9, PDGFR-2, PDGFR2, RHEPDGFRA..."}, {"node_size": 10, "node_shape": "box", "y": 830.0, "degree": 3, "color": "#67a667", "x": 585.0, "border_width": 1, "id_num": "PDGFRB", "id": "PDGFRA, CD140A, GAS9, PDGFR-2, PDGFR2, RHEPDGFRA..."}, {"node_size": 10, "node_shape": "box", "y": 790.5, "degree": 18, "c
# ...
